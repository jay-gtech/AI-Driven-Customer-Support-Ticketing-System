# %%
import sys
import os

PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
import pandas as pd
from src.preprocessing.text_cleaner import preprocess_dataframe

df = pd.read_csv("../data/raw/tickets.csv")
df = preprocess_dataframe(df)

df[["subject", "description", "clean_text"]].head()
# Out:
#                                   subject  \
# 0         Unable to login with my account
# 1         Password reset link not working
# 2         Unable to login with my account
# 3         Password reset link not working
# 4  Account locked after multiple attempts
#
#                                          description  \
# 0  Unable to login with my account. This issue is...
# 1  Password reset link not working. This issue is...
# 2  Unable to login with my account. This issue is...
# 3  Password reset link not working. This issue is...
# 4  Account locked after multiple attempts. This i...
#
#                                           clean_text
# 0  unable to login with my account unable to logi...
# 1  password reset link not working password reset...
# 2  unable to login with my account unable to logi...
# 3  password reset link not working password reset...
# 4  account locked after multiple attempts account...

# %%
df["clean_text_length"] = df["clean_text"].apply(lambda x: len(x.split()))

df["clean_text_length"].describe()
# Out:
# count    1000.000000
# mean       25.296000
# std         1.758259
# min        23.000000
# 25%        23.000000
# 50%        25.000000
# 75%        27.000000
# max        29.000000
# Name: clean_text_length, dtype: float64

# %%
df.to_csv("../data/processed/tickets_cleaned.csv", index=False)
