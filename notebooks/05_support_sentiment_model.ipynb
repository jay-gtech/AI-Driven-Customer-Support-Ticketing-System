# %%
import sys
import os

PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
import pandas as pd

df = pd.read_csv("../data/raw/tickets.csv")

# %%
df
# Out:
#      ticket_id                                 subject  \
# 0            1         Unable to login with my account
# 1            2         Unable to login with my account
# 2            3         Password reset link not working
# 3            4  Account locked after multiple attempts
# 4            5       Getting invalid credentials error
# ..         ...                                     ...
# 995        996                   Deactivate my account
# 996        997                 Want to upgrade my plan
# 997        998                   Deactivate my account
# 998        999                 Change registered email
# 999       1000                   Deactivate my account
#
#                                            description channel category  \
# 0    Unable to login with my account. Kindly check ...   email    Login
# 1    Unable to login with my account. Thank you for...   email    Login
# 2    Password reset link not working. Great service...     web    Login
# ...

# %%
from src.preprocessing.text_cleaner import preprocess_dataframe

df = preprocess_dataframe(df)

# %%
from src.models.support_sentiment_classifier import train_support_sentiment_model

model = train_support_sentiment_model(df)
# Out:
# Support Sentiment Classification Report:
#
#               precision    recall  f1-score   support
#
#        Angry       1.00      1.00      1.00        39
# Appreciative       1.00      1.00      1.00        43
#         Calm       1.00      1.00      1.00        35
#   Frustrated       1.00      1.00      1.00        41
#       Urgent       1.00      1.00      1.00        42
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200

# %%
import joblib
joblib.dump(model, "../models/support_sentiment_model.pkl")
# Out:
# ['../models/support_sentiment_model.pkl']
